# %%
import Validations_module as vd
import Database_connection as db_con
import Card_generate_module as cg
import Registration_process as reg_p
import Login_process as log_p

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd
import random
import random
import getpass
from decimal import Decimal
import pymysql
import re

# %%
def user_registration():

    print("welcome to registration page")
    print("kindly register your self to use banking facility")
    #storing input in the variable
    while True:
        res=input("Enter 'exit' to quit registration process else 1 to proceed")
        if res.lower()!='exit':
            if not reg_p.user_input():
                
                        
                    
                print("Registration unsucessful, please try again")
            else:
                print("Registration is sucessful")
        else:
            break

# %%
def login_1():
    print("Please enter your details to login")
    print("enter your name")
    print("enter your password")
    name=input("name")
    password=getpass.getpass("password")

    
    connection = db_con.database_connection()
    
    try:
        with connection.cursor() as cursor:
            select_name_password="select * from banking.Users_reg_data where username=%s and password=%s"
            cursor.execute(select_name_password, (name,password))
            result = cursor.fetchall()
            #print(result[0]['UserID'])
            d_name=result[0]['UserName']
            d_pass=result[0]['password']
            user_id=result[0]['UserID']
    except Exception as e:
        print("error Occurred",e,"Please try after sometime")
        return False
    finally:
        connection.close()
    
    #print(user_id,d_name,d_pass )

    if (name.strip().lower()==d_name.lower()) & (password.strip().lower()==d_pass.lower()):
        print("login sucessfully")
        while True:
            print("please select to any below option")
        
            print("1 for check account balance")
        
            print("2 for check list of beneficiaries")
        
            print("3 for check list of cards")
        
            print("4 to add beneficiary")
        
            print("5 to update account info")
        
        
            print("6 to transfer funds")
        

        
            print("7 to change pin")
        
            print("8 to register new card")
        
            print("9 to add fund")
        
            print("10 to view transactions")
        
            print("11 to exit")
        
            response=input()
            print()
        
            if response=='1':
                d=log_p.chcek_balance(user_id)
                if not d:
                    print("balance can't be fetched")
                print("Your current account details is")
                print('Account number : ', d['Account_number'])
                print('Account Balance : ', d['Amount'])
            
                print()
        
            elif response=='2':
                if log_p.get_beneficiary(user_id):
                    print("Last request was sucessfull")
                
                    print()
      
            
            elif response=='3':
                if log_p.get_cards(user_id):
                    print("Last request was sucessfull")
                
                    print()    
            
            elif response=='4':
                print("Enter the beneficiary_name")
                b_name=input()
                while True:
                    if not vd.validate_name(b_name):
                        b_name=input("Enter the benficiary name again")
                    else:
                        break
                b_account=input("Enter the beneficairy account number")
                while True:
                    if not vd.validate_account(b_account):
                        b_account=input("Enter the beneficiary account number again")
                    else:
                        break
                bank_name=input("Enter the beneficiary bank name")
                while True:
                    if not vd.validate_bank_name(bank_name):
                        bank_name=input("enter the beneficiary bank name")
                    else:
                        break
                    
                if log_p.add_beneficiary(user_id,b_name,b_account,bank_name):
                    print("Last Transaction was sucessful")
                print()
                
            elif response=='5':
                if log_p.update_account_info(user_id):
                    print("Details updated sucessfully")
                print()
            
            elif response=='6':
                if log_p.fund_transfer(user_id):
                    print("Details updated sucessfully")
                print()
                
            elif response=='7':
                card_type=input("Enter your card type Debit , credit")
                while True:
                    if card_type.lower()=='debit' or card_type.lower()=='credit':
                        break
                    else:
                        card_type=input("Enter your card type Debit , credit")
            
                print("enter old pin")
                old_pin=log_p.enter_new_pin()
                
                print("enter new pin")
                new_pin=log_p.enter_new_pin()
                
                if log_p.change_pin(user_id, card_type, old_pin, new_pin):
                    print("Last Transaction was sucessful")
                
                print()
        
            elif response=='8':
                if log_p.reg_new_card(user_id):
                    print("Last Transaction was sucessful")
                print()        
            
            elif response=='9':
                if log_p.add_fund(user_id):
                    print("Last Transaction was sucessful")
                print()
        
            elif response=='10':
                if log_p.view_transactions(user_id):
                    print("Last Transaction was sucessful")
                print()        
            
            
            elif response=='11':
                break
                

            
    return

# %%
def main():
    while True:
        print("Welcome to Banking Application:")

        print("Enter 1 to login")
        print("Enter 2 to registration")
        print("Enter 3 to logout ")
        print()
    
        response=input("Enter your option")
        if response=='1':
            login_1()
        elif response=='2':
            user_registration()
        elif response=='3':
            print("Thank you for your time")
            break
        else:
            print("Invalid option")
            
if __name__ == "__main__":
    main()
# Out:
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option2
# welcome to registration page
# kindly register your self to use banking facility
# Enter 'exit' to quit registration process else 1 to proceed1
# 0
# Enter your name
# Enter your name again
# Enter your name 1234
# Enter your name again
# Enter your name Lila shah
# Enter your password: ········
# Enter your password again ,with atleast 6 charcter long including special charcter and one capital
# Enter your password: ········
# Enter your address 12
# Enter your address again
# Enter your address mg
# Enter your address again
# Enter your address mg road 89, @
# Enter your address again
# Enter your address mg road 89 ,
# Enter your adharnumber 098
# Enter your adharnumber again
# Enter your adharnumber Ai8
# Enter your adharnumber again
# Enter your adharnumber 987678987656
# Enter your mobile_no 91898
# Enter your mobile_no again
# Enter your mobile_no 919809098789
# Registration is sucessful
# Enter 'exit' to quit registration process else 1 to proceedexit
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option1
# Please enter your details to login
# enter your name
# enter your password
# nameLila
# password········
# error Occurred tuple index out of range Please try after sometime
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your optionLila shah
# Invalid option
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option1
# Please enter your details to login
# enter your name
# enter your password
# nameLila shah
# password········
# login sucessfully
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 11
#
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option1
# Please enter your details to login
# enter your name
# enter your password
# namelila shah
# password········
# error Occurred tuple index out of range Please try after sometime
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option1
# Please enter your details to login
# enter your name
# enter your password
# nameLila shah
# password········
# login sucessfully
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 1
#
# Your current account details is
# Account number :  2209391278
# Account Balance :  0.00
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 2
#
# No records found.
# Last request was sucessfull
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 3
#
# User ID:  13 username:  Lila shah card type :  credit XXXX XXXX 2900
# User ID:  13 username:  Lila shah card type :  debit XXXX XXXX 5848
# Last request was sucessfull
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 4
#
# Enter the beneficiary_name
# Shiya
# Enter the beneficairy account number9876876787
# Enter the beneficiary bank name123 bank@
# enter the beneficiary bank nameuno bank
# Beneficiary 'Shiya' added successfully for user '13'.
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 4
#
# Enter the beneficiary_name
# Shiya
# Enter the beneficairy account number9876876787
# Enter the beneficiary bank namebank
# Beneficiary account '9876876787' already exists for user '13'.
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 5
#
# Please enter your option to proceed
#  1 for address
#  2 for mobilenumber
# Enter your option 1, 21
# enter new address to updateJh45 road
# Name:  Lila shah
# Address:  Jh45 road
# MobileNumber:  919809098789
# AadharNumber:  XXXX XXXX 7656
# Details updated sucessfully
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 5
#
# Please enter your option to proceed
#  1 for address
#  2 for mobilenumber
# Enter your option 1, 22
# enter new mobile number to update919878987600
# Name:  Lila shah
# Address:  Jh45 road
# MobileNumber:  919878987600
# AadharNumber:  XXXX XXXX 7656
# Details updated sucessfully
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 6
#
# Enter sender's account number: 2209391278
# Enter the beneficiary details
# Enter the beneficiary's account number: 9876876787
# Enter the amount to transfer: -9
# Amount must be greater than zero.
# Enter the amount to transfer: 90
# Insufficient balance.
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 9
#
# Enter sender's account number: 2209391278
# Enter the amount to add: 100
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 6
#
# Enter sender's account number: 2209391278
# Enter the beneficiary details
# Enter the beneficiary's account number: 9876876787
# Enter the amount to transfer: 10
# Transfer of 10 successful.
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 11
#
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option1
# Please enter your details to login
# enter your name
# enter your password
# nameLila shah
# password········
# login sucessfully
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 10
#
# sender_id 13 beneficiary_id 6 amount 10.00 transaction_date 2024-07-12 11:52:47 username Lila shah beneficiary_name Shiya
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 7
#
# Enter your card type Debit , creditc
# Enter your card type Debit , creditcredit
# enter old pin
# Enter 4-digit PIN: ········
# enter new pin
# Enter 4-digit PIN: ········
# Enter 'exit' to quit registration process else 1 to proceed: 1
# No 'credit' card found for user with provided PIN.
# Enter 'exit' to quit registration process else 1 to proceed: exit
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 7
#
# Enter your card type Debit , creditdebit
# enter old pin
# Enter 4-digit PIN: ········
# enter new pin
# Enter 4-digit PIN: ········
# Invalid PIN. Please enter a 4-digit numeric PIN.
# Enter 4-digit PIN: ········
# Invalid PIN. Please enter a 4-digit numeric PIN.
# Enter 4-digit PIN: ········
# Enter 'exit' to quit registration process else 1 to proceed: 1
# PIN updated successfully for '13' with 'debit' card.
# Enter 'exit' to quit registration process else 1 to proceed: exit
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 8
#
# enter the card number to register09898778778767876
# enter the card number to register98987787787678761
# enter the card number to register9876789876567876
# enter the cvv ········
# enter the cvv to register········
# enter the pin ········
# enter the card_type 1 debit 2 credit1
# Last Transaction was sucessful
#
# please select to any below option
# 1 for check account balance
# 2 for check list of beneficiaries
# 3 for check list of cards
# 4 to add beneficiary
# 5 to update account info
# 6 to transfer funds
# 7 to change pin
# 8 to register new card
# 9 to add fund
# 10 to view transactions
# 11 to exit
# 11
#
# Welcome to Banking Application:
# Enter 1 to login
# Enter 2 to registration
# Enter 3 to logout
#
# Enter your option3
# Thank you for your time

# %%
#2209391278 # 9876876787
